# %%
import pandas as pd 
import json

from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PowerTransformer
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
import matplotlib.pyplot as plt

# %%
def load_molecular_data(smiles):
    print(smiles)
    with open(f'../copol_prediction/output/molecule_properties/{smiles}.json', 'r') as handle:
        d = json.load(handle)

    # for charges, fukui_electrophilicity, fukui_nucleophilicity, fukui_radical
    # it is a dict. take the min, max, mean of the values of the dict and make a new key/value pairs in the root 
    # of d
    for key in ['charges', 'fukui_electrophilicity', 'fukui_nucleophilicity', 'fukui_radical']:
        d[key + '_min'] = min(d[key].values())
        d[key + '_max'] = max(d[key].values())
        d[key + '_mean'] = sum(d[key].values()) / len(d[key].values())

    d['dipole_x'] = d['dipole'][0]
    d['dipole_y'] = d['dipole'][1]
    d['dipole_z'] = d['dipole'][2]

    return d

# %%
def molecular_features(smiles):
    d = load_molecular_data(smiles)
    # select only the keys for which we have float values
    d = {k: v for k, v in d.items() if isinstance(v, float)}
    return d

# %%
molecular_features('C_C=C_C')
# Out:
# C_C=C_C
# {'ip': 13.682973015266317,
#  'ip_corrected': 8.836973015266317,
#  'ea': 1.2218398518750326,
#  'homo': -0.3816405868399534,
#  'lumo': -0.1874791546885192,
#  'global_electrophilicity': 0.27258173104659283,
#  'global_nucleophilicity': -8.836973015266317,
#  'best_conformer_energy': -12.612394464140023,
#  'charges_min': -0.10224603368115683,
#  'charges_max': 0.04109184075729364,
#  'charges_mean': -1.9024134119878985e-16,
#  'fukui_electrophilicity_min': -0.05083731556660036,
#  'fukui_electrophilicity_max': 0.15345645443935063,
#  'fukui_electrophilicity_mean': 0.08333333333333313,
#  'fukui_nucleophilicity_min': -0.026684857821392627,
#  'fukui_nucleophilicity_max': 0.13523914792194044,
#  'fukui_nucleophilicity_mean': 0.08333333333340077,
#  'fukui_radical_min': -0.038761080705294174,
#  'fukui_radical_max': 0.11937515617831551,
#  'fukui_radical_mean': 0.08333333333336708,
#  'dipole_x': -3.718452829648182e-07,
#  'dipole_y': -3.899439447074193e-07,
#  'dipole_z': -2.845134707431372e-09}

# %%
with open('all_data_filtered.json', 'r') as file:
    data = json.load(file)

def is_within_deviation(actual_product, expected_product, deviation=0.10):
    if expected_product == 0:
        return actual_product == 0
    return abs(actual_product - expected_product) / abs(expected_product) <= deviation


for entry in data:
    r1 = entry['reaction_constant_constant_1']
    r2 = entry['reaction_constant_constant_1']
    #r_product = entry.get('r-product')
    
    #if r_product is None:
        #entry['r-product_filter'] = False
        #continue
    
    #actual_product = r1 * r2
    
    # Check for division by zero
    #if r_product == 0:
        #deviation = float('inf') if actual_product != 0 else 0
    #else:
        #deviation = abs(actual_product - r_product) / abs(r_product)
    
    #if is_within_deviation(actual_product, r_product):
        #entry['r-product_filter'] = False
    #else:
        #entry['r-product_filter'] = True # reaction should be filtered out


def filter_conf_intervals(row):
    if 'conf_intervals' in row and 'constant_conf_1' in row['conf_intervals'] and 'constant_conf_2' in row['conf_intervals']:
        conf_1 = row['conf_intervals']['constant_conf_1']
        conf_2 = row['conf_intervals']['constant_conf_2']
        
        # Ensure 'r1' and 'r2' are correctly retrieved from the row
        r1 = row.get('r_values', {}).get('constant_1')
        r2 = row.get('r_values', {}).get('constant_2')
        
        if r1 is not None and r2 is not None and conf_1 is not None and conf_2 is not None:
            # Filter condition: Confidence intervals should not be greater than the corresponding r-values
            return (conf_1 <= 1 * r1) and (conf_2 <= 1 * r2)
    
    # If conditions are not met, return True by default, meaning the row will not be filtered out
    return True

# %%
# Convert JSON data to DataFrame
df_full = pd.DataFrame(data)

print('Initial datapoints: ', len(df_full))
df_full = df_full[df_full['r_conf_filter'] == True]
print('Datapoints after confidence filter:', len(df_full))

# Separate the filtered data
df_filtered = df_full[df_full['r-product_filter'] == True]
print('Datapoints after r-product filter:', len(df_filtered))
# Out:
# Initial datapoints:  2121
# Datapoints after confidence filter: 2121
# Datapoints after r-product filter: 1759

# %%
df_filtered['r1'] = df_full['reaction_constant_constant_1']
df_filtered['r2'] = df_full['reaction_constant_constant_2']

#df_filtered['calculation_method'].fillna('None', inplace=True)
df_filtered['reaction_polymerization_type'].fillna('None', inplace=True)

df_filtered.dropna(subset=['r1', 'r2',  'monomer1_s', 'monomer2_s', 'reaction_temperature', 'reaction_polymerization_type'], inplace=True)

# if polymerization type is "bulk" then set solvent to "bulk"
df_filtered.loc[df_filtered['reaction_polymerization_type'] == 'bulk', 'reaction_solvent'] = 'bulk'

df_filtered.dropna(subset=['reaction_solvent_smiles'], inplace=True)

#df_filtered.drop(columns=['r-product_filter', 'r_values', 'r-product', 'monomer1_data', 'monomer2_data', 'conf_intervals'], inplace=True)

print(len(df_filtered))
# Out:
# 993
# /var/folders/tv/b0y73fwd4zn44s4jmxl5169w0000gn/T/ipykernel_24842/200766071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['r1'] = df_full['reaction_constant_constant_1']
# /var/folders/tv/b0y73fwd4zn44s4jmxl5169w0000gn/T/ipykernel_24842/200766071.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['r2'] = df_full['reaction_constant_constant_2']
# /var/folders/tv/b0y73fwd4zn44s4jmxl5169w0000gn/T/ipykernel_24842/200766071.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filtered['reaction_polymerization_type'].fillna('None', inplace=True)
# /var/folders/tv/b0y73fwd4zn44s4jmxl5169w0000gn/T/ipykernel_24842/200766071.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['reaction_polymerization_type'].fillna('None', inplace=True)
# /var/folders/tv/b0y73fwd4zn44s4jmxl5169w0000gn/T/ipykernel_24842/200766071.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.dropna(subset=['r1', 'r2',  'monomer1_s', 'monomer2_s', 'reaction_temperature', 'reaction_polymerization_type'], inplace=True)
# /var/folders/tv/b0y73fwd4zn44s4jmxl5169w0000gn/T/ipykernel_24842/200766071.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.dropna(subset=['reaction_solvent_smiles'], inplace=True)

# %%
df_filtered_flipped = []

# create the same rows, but with flipped monomers, i.e. monomer1_s <-> monomer2_s, monomer1 <-> monomer2, and r1 <-> r2
for index, row in df_filtered.iterrows():
    flipped_row = row.copy()
    flipped_row['monomer1_s'] = row['monomer2_s']
    flipped_row['monomer2_s'] = row['monomer1_s']
    flipped_row['monomer1'] = row['monomer2']
    flipped_row['monomer2'] = row['monomer1']
    flipped_row['r1'] = row['r2']
    flipped_row['r2'] = row['r1']
    df_filtered_flipped.append(flipped_row)

df_filtered_flipped = pd.DataFrame(df_filtered_flipped)
df_filtered_flipped
# Out:
#                            _id  \
# 0     67ee4591d974be3a9ef4a1b5
# 1     67ee4591d974be3a9ef4a1b6
# 4     67ee45dc8a67c60235f7d946
# 5     67ee45dc8a67c60235f7d949
# 6     67ee45dc8a67c60235f7d94a
# ...                        ...
# 2112  67ee85448a67c60235f7e4bb
# 2117  67ee85448a67c60235f7e4c1
# 2118  67ee85448a67c60235f7e4c2
# 2119  67ee85448a67c60235f7e4c3
# 2117  2025-04-03T12:55:32.335000  ...
# 2118  2025-04-03T12:55:32.340000  ...
# 2119  2025-04-03T12:55:32.347000  ...
# 2120  2025-04-03T12:55:32.356000  ...
#
#                                           original_data  \
# 0     {'source': 'https://doi.org/10.21767/2472-1123...
# 1     {'source': 'https://doi.org/10.21767/2472-1123...
# 4     {'source': '10.1002/pola.208882', 'PDF_name': ...
# 5     {'source': 'Journal of Polymer Science Vol. XX...
# 6     {'source': 'Journal of Polymer Science Vol. XX...
# ...                                                 ...
# 2112  {'source': 'https://doi.org/10.1002/pol.1969.1...
# 2117  {'source': 'https://doi.org/10.1002/app.30961'...
# 2118  {'source': 'https://doi.org/10.1002/app.30961'...
# 2119  {'source': 'https://doi.org/10.1002/app.1995.0...
# 2120  {'source': 'https://doi.org/10.1002/app.1995.0...
#
#                                      monomer_references r-product_filter  \
# 0     [67ee4591d974be3a9ef4a1b3, 67ee4591d974be3a9ef...             True
# 1     [67ee4591d974be3a9ef4a1b3, 67ee4591d974be3a9ef...             True
# 4     [67ee45dc8a67c60235f7d944, 67ee45dc8a67c60235f...             True
# 5     [67ee45dc8a67c60235f7d947, 67ee45dc8a67c60235f...             True
# 6     [67ee45dc8a67c60235f7d947, 67ee45dc8a67c60235f...             True
# ...                                                 ...              ...
# 2112  [67ee45dc8a67c60235f7d945, 67ee85428a67c60235f...             True
# 2117  [67ee4b228a67c60235f7d9ef, 67ee60068a67c60235f...             True
# 2118  [67ee4b228a67c60235f7d9ef, 67ee55728a67c60235f...             True
# 2119  [67ee53538a67c60235f7db6e, 67ee46088a67c60235f...             True
# 2120  [67ee53538a67c60235f7db6e, 67ee46088a67c60235f...             True
#
#      r_conf_filter  reaction_method reaction_r_product reaction_Q-value  \
# 0             True              NaN                NaN              NaN
# 1             True              NaN                NaN              NaN
# 4             True          solvent                NaN              NaN
# 5             True          solvent                NaN              NaN
# 6             True          solvent                NaN              NaN
# ...            ...              ...                ...              ...
# 2112          True          solvent                NaN              NaN
# 2117          True             bulk                NaN              NaN
# 2118          True             bulk                NaN              NaN
# 2119          True       suspension                NaN              NaN
# 2120          True       suspension                NaN              NaN
#
#      reaction_e-Value     r1      r2
# 0                 NaN  0.393  0.5880
# 1                 NaN  0.430  0.6270
# 4                 NaN  0.540  1.2800
# 5                 NaN  0.700  1.5000
# 6                 NaN  0.460  0.4100
# ...               ...    ...     ...
# 2112              NaN  0.350  1.3500
# 2117              NaN  0.960  0.9300
# 2118              NaN  1.110  0.9900
# 2119              NaN  0.575  0.0646
# 2120              NaN  0.140  0.0450
#
# [993 rows x 30 columns]

# %%
from rdkit import Chem
from rdkit.Chem.Descriptors import MolLogP

# %%
# now, add the features for each monomer by loading the corresponding JSON file with `molecular_features` based on the monomer{i}_s column
def add_molecular_features(df): 
    new_rows = []
    for index, row in df.iterrows():
        try:
            monomer1_s = row['monomer1_s']
            monomer2_s = row['monomer2_s']
            monomer1 = row['monomer1']
            monomer2 = row['monomer2']
            temperature = row['reaction_temperature']
            solvent = row['reaction_solvent_smiles']
            #calculation_method = row['calculation_method']
            polymerization_method = row['reaction_polymerization_type']
            if solvent == 'bulk':
                solvent_logp = 0
            else:
                solvent_logp = MolLogP(Chem.MolFromSmiles(solvent))

            monomer1_data = molecular_features(monomer1_s)
            monomer2_data = molecular_features(monomer2_s)
            
            # add _1 to the keys of monomer1_data and _2 to the keys of monomer2_data
            monomer1_data = {f'{k}_1': v for k, v in monomer1_data.items()}
            monomer2_data = {f'{k}_2': v for k, v in monomer2_data.items()}

            # now, create new dict with all the data 
            new_row = {**row, **monomer1_data, **monomer2_data, 'temperature': temperature, 'solvent': solvent, 'polymerization_method': polymerization_method, 'solvent_logp': solvent_logp}

            new_rows.append(new_row)
        except FileNotFoundError as e: 
            print(f"File not found: {e}")
    return pd.DataFrame(new_rows)

# %%
df_filtered = add_molecular_features(df_filtered)
df_filtered_flipped = add_molecular_features(df_filtered_flipped)
# Out:
# C=C(C)C(=O)OCc1ccccc1
# C=C(C)C(=O)OCCN(CC)CC
# C=C(C)C(=O)OCc1ccccc1
# C=C(C)C(=O)OCCN(CC)CC
# C=CC(=O)C1CNCCO1
# C=C(C)C(=O)OC
# C=COC(=O)c1ccccc1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# CCCC[Sn+2]CCCC.O=C([O-])/C=C\C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCCC[Sn+2]CCCC.O=C([O-])/C=C\\C(=O)[O-].json'
# CCCC[Sn+2]CCCC.O=C([O-])/C=C\C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCCC[Sn+2]CCCC.O=C([O-])/C=C\\C(=O)[O-].json'
# C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC.json'
# C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC.json'
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)OCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=Cc1ccccc1
# C=COCC(C)C
# C=Cc1ccccc1
# C=COCC(C)C
# C=C(C)C(=O)OCC=Cc1ccccc1
# C=C(C)C(=O)OCC
# C=C(C)C(=O)OCC=Cc1ccccc1
# C=C(C)C(=O)OCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=C(C)C(=O)C1CC(C)(C)NC(C)(C)C1
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=CC=CF
# C=Cc1ccccc1
# C=CC=CF
# C=Cc1ccccc1
# C=CC=CF
# C=CC#N
# C=CC=CF
# C=CC(=C)C
# C=CC=CF
# C=C(C)c1ccccc1
# C=CC=CF
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccccc1C(=O)O
# C=CCl
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCCN(C)C
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCCN(C)C
# C=C(C)C(=O)OCCO
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCCO
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=C(F)C(N)=O
# C=CC(N)=O
# C=CC(=O)O
# C=CC(N)=O
# C=CC(=O)O
# C=CC(N)=O
# C=CC[N+](C)(C)CC=C.[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=CC[N+](C)(C)CC=C.[Cl-].json'
# C=CC(=O)O
# C=CC[N+](C)(C)CC=C.[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=CC[N+](C)(C)CC=C.[Cl-].json'
# C=C(C)C(=O)OCC1CO1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC1CO1
# C=C(C)C(=O)OC
# C=C(C)C(=O)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)O
# C=C(C)C(=O)OC
# C=CC(C)=O
# C=Cc1ccccc1
# C=CC(C)=O
# C=Cc1ccccc1
# C=CC(C)=O
# C=Cc1ccccc1
# C=CC(C)=O
# C=Cc1ccccc1
# C=CC(=O)Cl
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCO
# C=CC(N)=O
# C=Cc1cc(O)ccc1O
# C=CN(C(=O)[O-])C(C)(C)C
# C=CCC(=O)[O-]
# C=CN(C(=O)[O-])C(C)(C)C
# C=CCC(=O)[O-]
# C=C(C)C(=O)OC
# C=CC(=O)OCC(C)C
# C=C(C)C(=O)OC
# C=CC(=O)OC(C)CC
# C=C(C)C(=O)OC(C)(C)C
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC(C)(C)C
# C=CC(=O)OC(C)CC
# C=C(C)C(=O)OC(C)(C)C
# C=CC(=O)OCC(C)C
# C=C(C)C(=O)OC(C)(C)C
# C=CC(=O)OC(C)(C)C
# C=Cc1cc(O)ccc1O
# C=CC#N
# C=CC(=O)OC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(=O)C(=C)C
# C=Cc1ccccc1
# C=C(C)C(=O)OC(=O)C(=C)C
# C=C(C)C#N
# C=CC(=O)OC(=O)C=C
# C=Cc1ccccc1
# C=CC(=O)OC(=O)C=C
# C=C(C)C#N
# C=CC(=O)OC(=O)C=C
# C=CCCl
# C=CC(=O)OC
# C=Cc1ccccc1
# C=C(Cl)Cl
# C1=Cc2ccccc2C1
# C=Cc1ccccc1Cl
# C1=Cc2ccccc2C1
# C=C(Cl)Cl
# C=C(C)C(=O)O
# C=Cc1ccccc1Cl
# C=C(C)C(=O)O
# C=C(C)C(=O)OC
# C=Cc1ccccn1
# C=COC(C)=O
# C=Cc1ccccn1
# C=C(C)C(=O)OC
# C=C(Cl)C(=O)OC
# C=CC#N
# C=C(Cl)C(=O)OC
# C=CCl
# C=CC(C)(C)C
# C=COC(C)=O
# FC(F)=C(Cl)Cl
# C=COC(C)=O
# C=CC#N
# C=CCl
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# C=Cc1ccccc1
# ClC(Cl)=C(Cl)C(Cl)=C(Cl)Cl
# C=CCl
# C1=CC2C=CC1C2
# C=C(Cl)Cl
# C1=CC2C=CC1C2
# C=CC#N
# C1=CC2C=CC1C2
# C=CC(=O)OCC
# C1=CC2C=CC1C2
# C=C(C)C(=O)OC
# C1=CC2C=CC1C2
# C1=Cc2cccc3cccc1c23
# C=C(C)C(=O)OC
# C1=Cc2cccc3cccc1c23
# C=C(C)C(=O)OCC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=CC[N+](C)(C)CC=C.[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=CC[N+](C)(C)CC=C.[Cl-].json'
# C=C(C)C(=O)OC
# C=CC[N+](C)(C)CC=C.[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=CC[N+](C)(C)CC=C.[Cl-].json'
# C=CC(=O)N(C)C
# C=CC(=O)NC(C)(C)CS(=O)(=O)[O-].[Na+]
# C=CC(=O)N(C)C
# C=CC(=O)NC(C)(C)CC(=O)[O-].[Na+]
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCN(CC)CC
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=C(Cl)C(=O)OCCCCCC
# C=C(C)C(=O)OC
# C=C(Cl)C(=O)OC1CCCCC1
# C=CC#N
# C=COC(=O)CCl
# C=CC#N
# C=COC(=O)C(Cl)Cl
# C=CC#N
# C=CC(N)=O
# C=COC(C)=O
# C=CC(=O)OC
# C=Cc1ccccc1
# C=Cc1cccc([N+](=O)[O-])c1
# C=Cc1ccccc1
# C=Cc1cccc([N+](=O)[O-])c1
# C=Cc1ccc(Cl)cc1
# C=Cc1cccc([N+](=O)[O-])c1
# C=Cc1ccc(Cl)cc1
# C=Cc1cccc([N+](=O)[O-])c1
# C=C(C)C(=O)OC
# C=Cc1cccc([N+](=O)[O-])c1
# C=C(C)C(=O)OC
# C=Cc1cccc([N+](=O)[O-])c1
# C=CCCCCCC
# C=C(C#N)C(=O)OC
# C=CCCCCCC
# C=C(C#N)C(=O)OC
# C=Cc1ccccc1
# COC(=O)C(C#N)=Cc1ccccc1
# C=Cc1ccccc1
# COC(=O)C(C#N)=Cc1ccccc1
# C=Cc1ccccc1
# O=C(/C=C/C(=O)N1CCCC1=O)N1CCCC1=O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(/C=C/C(=O)N1CCCC1=O)N1CCCC1=O.json'
# C=Cc1ccccc1
# O=C(/C=C/C(=O)N1CCCC1=O)N1CCCC1=O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(/C=C/C(=O)N1CCCC1=O)N1CCCC1=O.json'
# C=C(C)C(=O)OCC(F)(Cl)C(F)(F)F
# C=Cc1ccccc1
# C=CC(=O)OC
# C=CC#N
# C=CC(=O)OCCCC
# C=CC#N
# C=CC(=O)OCCCCCCCCCCCC
# C=CC#N
# C=CC(=O)OCCCCCCCCCCCCCCCCCC
# C=CC#N
# C=Cc1ccccc1
# C=CC(=O)OC
# C=Cc1ccccc1
# C=CC(=O)OC
# C=CC(=O)OC
# C=CSC
# C=Cc1ccccc1
# C=CSC
# C=COC(C)=O
# C=CSC
# C=Cc1ccccc1
# C=CS(C)(=O)=O
# C=C(C)C#N
# C=Cc1ccccc1
# C=C(C)C#N
# C=Cc1ccccc1
# C=C(C)C#N
# C=Cc1ccccc1
# ClCC=Cc1ccccc1
# O=C1C=CC(=O)O1
# C1=Cc2cccc3cccc1c23
# C=Cc1ccccc1
# C1=Cc2cccc3cccc1c23
# C=C(C)C(=O)OC
# C1=Cc2cccc3cccc1c23
# C=C(C)C(=O)OC
# C1=Cc2cccc3cccc1c23
# O=C1C=CC(=O)O1
# C=C(C)C(=O)OCc1ccco1
# C=C(C)C(=O)OC
# O=C(O)C=CC=CC(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)C=CC=CC(=O)O.json'
# O=C(O)C=CC=CC(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)C=CC=CC(=O)O.json'
# CCOC(=O)/C=C/C=C/C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C=C/C(=O)[O-].json'
# CCOC(=O)/C=C/C=C/C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C=C/C(=O)[O-].json'
# C=C(CC)C(=O)O
# C=C(C)C(=O)O
# C=CN(C)C(C)=O
# C=CCC(=O)[O-]
# C=CN(C)C(C)=O
# C=CCC(=O)[O-]
# C=CN(C)C(C)=O
# C=CCC(=O)[O-]
# C=CN(C)C(C)=O
# C=C(C)C(=O)OC
# C=CN(C)C(C)=O
# C=CC(=O)OC
# C=Cc1ccccc1
# C=CC[SiH](OCC)OCC
# C=COC(C)=O
# C=COC=O
# C=COC(C)=O
# C=COC(=O)CC
# C=COC(C)=O
# C=COC(=O)CCC
# C=COC(C)=O
# C=COC(=O)Cc1ccccc1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=COC=O
# C=C(C)C(=O)OC
# C=COC(C)=O
# C=C(C)C(=O)OC
# C=COC(=O)CC
# C=C(C)C(=O)OC
# C=COC(=O)CCC
# C=C(C)C(=O)OC
# C=COC(=O)Cc1ccccc1
# C=C(C)C(=O)OC
# C=COC(=O)c1ccccc1
# C=CNC(C)=O
# C=COC(C)=O
# C=CNC(C)=O
# C=C(C)C(=O)OC
# C(=Cc1ccccc1)c1ccccc1
# C=Cc1ccccc1
# C(=Cc1ccccc1)c1ccccc1
# C=Cc1ccccc1
# C(=Cc1ccccc1)c1ccccc1
# C1=Cc2cccc3cccc1c23
# C(=Cc1ccccc1)c1ccccc1
# C1=Cc2cccc3cccc1c23
# O=c1occo1
# C=COC(C)=O
# O=c1occo1
# C=CSC
# O=C1C=CCO1
# C=Cc1ccccc1
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCN(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCN(C)C
# C1=Cc2cccc3cccc1c23
# C=CC(=O)OC1CC(C)CCC1C(C)C
# C1=Cc2cccc3cccc1c23
# C=C(C)C(=O)OC1CC(C)CCC1C(C)C
# C=CC#N
# C=COCC(C)C
# C=CC(C)=O
# C=C(C)C(=O)NC
# C=CC#N
# C=CC(=O)OC
# C=C(C)C(=O)OC
# C=C(C)C(=O)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)O
# C=CC(=O)OC[c-]1cccc1.[Fe+2].c1cc[cH-]c1
# C=Cc1ccccc1
# C=CC(=O)OC[c-]1cccc1.[Fe+2].c1cc[cH-]c1
# C=CC(=O)OC
# C=CC(=O)OC[c-]1cccc1.[Fe+2].c1cc[cH-]c1
# C=C(C)C(=O)OC
# C=CC(=O)OC[c-]1cccc1.[Fe+2].c1cc[cH-]c1
# C=COC(C)=O
# C=C(C)C(=O)OCCO
# C=CC(N)=O
# C=C(C)C(=O)OCCO
# C=CC(N)=O
# C=C(C)C(=O)OCCO
# C=C(C)C(N)=O
# C=C(C)C(=O)OCCO
# C=C(C)C(N)=O
# C=C(C)C(=O)OCC(C)O
# C=CC(N)=O
# C=C(C)C(=O)OCC(C)O
# C=CC(N)=O
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(N)=O
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(N)=O
# C=C(C)C(=O)OCC(O)CCl
# C=CC(N)=O
# C=C(C)C(=O)OCC(O)CCl
# C=CC(N)=O
# C=C(C)C(=O)OCC(O)CCl
# C=C(C)C(N)=O
# C=C(C)C(=O)OCC(O)CCl
# C=C(C)C(N)=O
# C=C(C)C1=NCCO1
# C=CC(=O)OC
# C=C(C)C1=NCCO1
# C=CC(=O)OC
# C=C(C)C1=NCCO1
# C=COC(C)=O
# C=C
# O=C1C=CC(=O)O1
# C=C
# O=C1C=CC(=O)O1
# C=Cn1ccnc1
# C=Cc1ccccc1
# C=Cn1ccnc1
# C=Cc1ccccc1
# C=Cn1ccnc1
# C=C(C)C(=O)OC
# C=Cn1ccnc1
# C=C(C)C(=O)OC
# C=Cn1ccnc1
# C=C(C)C(=O)O
# C=Cn1ccnc1
# C=C(C)C(=O)O
# C=Cn1ccnc1
# C=CC(=O)O
# C=Cn1ccnc1
# C=CC(=O)O
# C=Cn1ccnc1
# C=CC#N
# C=Cn1ccnc1
# C=CC#N
# C=Cn1ccnc1
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# C=Cn1ccnc1
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# C=Cn1ccnc1
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# C=Cn1ccnc1
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# C=Cn1ccnc1
# COC(=O)/C=C/C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C/C(=O)OC.json'
# C=Cn1ccnc1
# COC(=O)/C=C/C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C/C(=O)OC.json'
# C=Cn1ccnc1
# CCOC(=O)C=CC(=O)OCC
# C=Cn1ccnc1
# CCOC(=O)C=CC(=O)OCC
# C=Cn1ccnc1
# O=C(O)/C=C/C(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C/C(=O)O.json'
# C=Cn1ccnc1
# O=C(O)/C=C/C(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C/C(=O)O.json'
# C=Cn1ccnc1
# O=C(O)/C=C\C(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C\\C(=O)O.json'
# C=Cn1ccnc1
# O=C(O)/C=C\C(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C\\C(=O)O.json'
# C/C=C\C(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C\\C(=O)O.json'
# C/C=C/C(=O)O
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C/C(=O)O.json'
# O=C(O)/C=C\Br
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C\\Br.json'
# O=C(O)/C=C/Br
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C/Br.json'
# O=C(O)/C=C\c1ccccc1
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C\\c1ccccc1.json'
# O=C(O)/C=C/c1ccccc1
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)/C=C/c1ccccc1.json'
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCC.C=C(CCC)COCCP(=O)(OC)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(C)C(=O)OCC.C=C(CCC)COCCP(=O)(OC)OC.json'
# C=Cc1ccc([N+](=O)[O-])cc1
# C=C(C)C(=O)F
# C=CC(=O)O
# C=CC(N)=O
# C=CC(=O)O
# C=CC(N)=O
# C=CC(=O)O
# C=CC(N)=O
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=CC=C
# C=C(C)C(=O)OC
# C=CC=C
# C=CC(=O)OC
# C=CC=C
# C=CC(=O)OCCCC
# C=CC=C
# C=C(C)C#N
# C=CC=C
# C=C(Cl)Cl
# C=CC(=O)O
# C=COC(C)=O
# C=CC(=O)O
# C=COC(C)=O
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=CCl
# CC(C)OC(=O)C=CC(=O)OC(C)C
# C=Cc1ccccc1
# CC(C)OC(=O)C=CC(=O)OC(C)C
# C=CC(=O)OC
# CC(C)OC(=O)C=CC(=O)OC(C)C
# C=CC#N
# CC(C)OC(=O)C=CC(=O)OC(C)C
# C=C(CO)C(=O)OCC
# C=C(C)C(=O)OC
# C=COC(C)=O
# C=CN1CCOC1=O
# C=C(Cl)Cl
# C=CN1CCOC1=O
# C=C(C)C(=O)OC
# C=CN1CCOC1=O
# C=Cc1ccccc1
# C=CC=C
# C=Cc1ccc(C)nc1
# C=CC=C
# C=Cc1ccccc1
# C=Cc1ccc(C)nc1
# C=CC(=O)NC(C)(C)C
# C=CC#N
# C=CC(=O)NC(C)(C)C
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1c1c(Br)cc(Br)cc1Br
# C=CC(=O)OC
# O=C1C=CC(=O)N1c1c(Br)cc(Br)cc1Br
# C=C(C)C(=O)OC
# C=CC#N
# C=C(CC(=O)O)C(=O)O
# C=CC#N
# C=C(CC(=O)O)C(=O)O
# C=CC#N
# C=C(CC(=O)O)C(=O)O
# C=C(C)C(=O)OCC1CO1
# C=C(C)C(=O)Oc1sccc1C
# C=C(C)C(=O)OCC1CO1
# C=C(C)C(=O)Oc1sccc1C
# C=CC(=C)Cl
# C=C(C)C(C)=O
# C=CC(=C)Cl
# C=C(C)C(=O)O
# C=Cc1ccccc1Cl
# C=CC(=O)OC
# C=Cc1ccccc1Cl
# C=CC(=O)OCC
# C=C(C)C(=O)OCC
# O=C1C=CC(=O)N1c1cccc(Cl)c1
# C=C(C)C(=O)OCCO
# C=CC(=O)OC(C)(C)C
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=CC#N
# C=C(CC(=O)[O-])C(=O)OC
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# O=S(=O)([O-])C=Cc1ccccc1.[Na+]
# C=C(Cl)C(=O)[O-].[Na+]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(Cl)C(=O)[O-].[Na+].json'
# C=C(C)C(=O)Oc1ccc([N+](=O)[O-])cc1[N+](=O)[O-]
# C=C(C)C(=O)Oc1cc(Cl)cc2c3cc(Cl)ccc3n(CCO)c12
# C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC.json'
# C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC.json'
# C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC.json'
# C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC.json'
# C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC.json'
# C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(CC(=O)[O-])C(=O)[O-].CCCC[Sn+](CCCC)CCCC.CCCC[Sn+](CCCC)CCCC.json'
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=CC#N
# C=Cc1ccccc1
# C=CC#N
# C=COC(C)=O
# C=C(Cl)Cl
# C=COC(C)=O
# C=C(Cl)Cl
# C=Cc1ccccn1
# C=COC(C)=O
# C=Cc1ccccn1
# C=COC(C)=O
# C=C(C)Cl
# C=COC(C)=O
# C=C(C)Cl
# C=CCl
# C=C(C)Cl
# C=CC#N
# C=C(C)Cl
# O=C1C=CC(=O)O1
# C/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C/Cl.json'
# C/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C/Cl.json'
# C/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C/Cl.json'
# C/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C/Cl.json'
# C/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C\\Cl.json'
# C/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C\\Cl.json'
# C/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C\\Cl.json'
# C/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C=C\\Cl.json'
# C=CC(N)=O
# C=CC(=O)O
# C=C(C)C(=O)OC
# C=Cc1ccc(C(C)(C)C)cc1
# C=C(C)C#N
# C=Cc1ccc(C)cc1
# C=C(C)C#N
# C=Cc1ccc(C)cc1
# C=Cc1ncc[nH]1
# C=C(C)C(=O)OCCC[Si](OC)(OC)OC
# C=C(C)C(=O)OC
# C=C(CO)C(=O)OCC
# C=CC=C
# C=Cc1cc(Cl)ccc1Cl
# C=CC=C
# C=CC#N
# C=CC=C
# C=CC=CC#N
# C=CC#N
# C=CC(=O)OC
# C=C(C)C(=O)OCC(O)CN1C(=O)c2ccccc2C1=O
# C=Cc1ccccc1
# C=C(C)C(=O)OCC(O)CN1C(=O)c2ccccc2C1=O
# C=Cc1ccccc1
# C=C(C)C(=O)OCC(O)CN1C(=O)c2ccccc2C1=O
# C=Cc1ccccc1
# CC(C)(C)OC(=O)C=CC(=O)OC(C)(C)C
# COC(=O)/C=C/C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(C)C(=O)O.C=C(C)C(=O)O.OCCOCCOCCOCCO.json'
# C=C(C)C(=O)OC1CCCCC1
# C=C(C)C(=O)O.C=C(C)C(=O)O.OCCOCCOCCOCCO
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(C)C(=O)O.C=C(C)C(=O)O.OCCOCCOCCOCCO.json'
# C=COC(C)=O
# C=CCl
# C=C(C)C(=O)OCC
# C=C(Cl)Cl
# C=CC(=O)OC[c-]1cccc1.[Fe+2].c1cc[cH-]c1
# O=C1C=CC(=O)O1
# C=CC(=C)Cl
# C=C(C)C(=O)OCC(C)C
# C=CC#N
# C=C(C)C(=O)OCC(O)CCl
# C=CC#N
# C=C(C)C(=O)OCC(O)CCl
# C=C(C)C(=O)[O-].[K+]
# C=CC#N
# C=C(C)C(=O)OC(C)(C)C
# C=C1CC(=O)OC1=O
# O=C1CCCCCO1
# O=C1CCCCO1
# O=C1CCCCCO1
# O=C1CCCCO1
# O=C1CCCCCO1
# O=C1CCCCO1
# O=C1CCCCCO1
# O=C1CCCCO1
# C=CC(N)=O
# C=CC[N+](C)(C)CC=C.[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=CC[N+](C)(C)CC=C.[Cl-].json'
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC1CO1
# C=C(C)C(=O)OC
# C=CC(=O)OCC
# C=C(C)C(=O)OC
# C=CC(=O)OCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=Cc1ccccc1
# O=C1C=CC(=O)N1
# C=C(Cl)Cl
# O=C1C=CC(=O)N1
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1
# C=Cc1ccccc1
# CC1=CC(=O)N(C)C1=O
# C=C(C)C(=O)OC
# CC1=CC(=O)N(C)C1=O
# C=C(/C=C/C(=O)OCC)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(/C=C/C(=O)OCC)OCC.json'
# C=C(/C=C/C(=O)OCC)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(/C=C/C(=O)OCC)OCC.json'
# C=C(/C=C/C#N)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(/C=C/C#N)OCC.json'
# C=Cc1ccccc1
# C=CN1CCOC1=O
# C=Cc1ccccc1
# C=CN1CCCC1=O
# C=Cc1ccccc1
# C=CC(=C)O[Si](C)(C)C
# C=CC#N
# C=CC(=C)O[Si](C)(C)C
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCC(O)CO
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCC(O)CO
# C=CC(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=COC(C)=O
# C=CC(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=Cc1ccccc1
# C=CC(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=C(C)C(=O)OC
# C=C(C)C(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=COC(C)=O
# C=C(C)C(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=Cc1ccccc1
# C=C(C)C(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=C(C)C(=O)OC
# C=CC=C
# C=CC#N
# C=CC=C
# C=CC#N
# C=C(Cl)Cl
# C=C(C)C(=O)OC
# C=C(Cl)Cl
# C=C(C)C(=O)OCc1ccccc1
# C=C(Cl)Cl
# C=C(C)C(=O)Cl
# C=C(Cl)Cl
# C=COC(C)=O
# C=Cc1ccccc1
# C=CC(=O)OC
# C=Cc1ccccc1
# C=CC(=O)OC
# C=COC(C)=S
# C=CN1C(=O)CCC1=O
# C=COC(C)=S
# C=CN1C(=O)c2ccccc2C1=O
# C=COC(C)=S
# C=Cn1c2ccccc2c2ccccc21
# C=C(C)C(=O)OC
# Cc1ccc(N2C(=O)C=CC2=O)cc1
# C=CC#N
# C=CC(C)=O
# C=CC#N
# C=CC(C)=O
# C=C(C)C(=O)OC
# C=Cc1ccc(OC)cc1
# C=C(C)C(=O)OCC1CO1
# C=CN1CCCC1=O
# C=C(C)C(=O)OCC1CO1
# C=CN1CCCC1=O
# C=C(C)C(=O)NCCCN(C)C
# C=CN1CCCC1=O
# C=Cc1ccccc1
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# C=Cc1ccccc1
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# C=Cc1ccccc1
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# C=Cc1ccccc1
# COC(=O)/C=C\C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)[O-].json'
# C=Cc1ccccc1
# N#C/C=C/C#N
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/N#C/C=C/C#N.json'
# C=Cc1ccccc1
# N#C/C=C\C#N
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/N#C/C=C\\C#N.json'
# C=Cc1ccccc1
# Cl/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C/Cl.json'
# C=Cc1ccccc1
# Cl/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C\\Cl.json'
# C=CCl
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# C=COC(C)=O
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# C=COC(C)=O
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# C=COC(C)=O
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# C=COC(C)=O
# Cl/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C/Cl.json'
# C=COC(C)=O
# Cl/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C\\Cl.json'
# O=C1C=CC(=O)O1
# C(=Cc1ccccc1)c1ccccc1
# ClCCCl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/ClCCCl.json'
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccc(Cl)cc2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccc(Cl)cc2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2cccc(Cl)c2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccccc2Cl)C1=O
# C=COCC(C)C
# C=COCCCl
# C=COCCCCCCCCCCCCCCCCCC
# C=COCCCl
# C=C(C)c1ccccc1
# C=COCCCl
# C=C(C)c1ccc(C)cc1
# C=COCCCl
# C=C(C)c1ccc(OC)cc1
# C=COCCCl
# C=CC(=O)OCCCCCCCCCCCCCCCCCCCCCC
# C=COC(C)=O
# C=CC(=O)OCCCCCCCCCCCCCCCCCCCCCC
# C=COC(C)=O
# C=CC(=O)OC
# C=C(C)N=C=O
# C=Cc1ccccc1
# C=C(C)N=C=O
# O=c1occo1
# C=COC(C)=O
# O=c1occo1
# C=CCl
# O=c1occo1
# C=C(C)C(=O)OC
# O=c1occo1
# C=CN1CCCC1=O
# C=C1CC(=O)N(c2ccc(OC)c(Cl)c2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2cc(Cl)ccc2OC)C1=O
# C=C(C)C(=O)OC
# C=CC(N)=O
# C=CC(=O)OCCCC
# C=CC(N)=O
# C=CC(=O)OCCCC
# C=CC(N)=O
# C=CC(=O)OCCCC
# C=CC#N
# COC(=O)C=C(CC(=O)OC)C(=O)OC
# C=C(CO)C(=O)OCC
# C=C(C)C(=O)OC
# C=C(CO)C(=O)OCC
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=CCl
# C=CCl
# C=COC(C)=O
# C=Cn1c2ccccc2c2ccccc21
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# C=Cn1c2ccccc2c2ccccc21
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(c1ccccc1)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(c1ccccc1)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)C
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# Cc1ccc(N(C)C)cc1N1C(=O)C=CC1=O
# C=C(C)C(=O)OC
# Cc1ccc(N(C)C)cc1N1C(=O)C=CC1=O
# C=C(C)C(=O)OC
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Cl
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Cl
# C=CC#N
# O=C1C=CC(=O)N1c1ccc(Cl)cc1
# C=CC#N
# O=C1C=CC(=O)N1c1ccc(Cl)cc1
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Br
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Br
# C=CC#N
# CCCCCCCCCCCCCCCCCCN1C(=O)C=CC1=O
# C=CC#N
# CCCCCCCCCCCCCCCCCCN1C(=O)C=CC1=O
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# C=Cc1cccc2c1[nH]c1ccccc12
# C=C(C)C(=O)OC
# C=Cc1cccc2c1[nH]c1ccccc12
# C=Cc1ccccc1
# C=C(Cl)CCl
# C=C(C)C(=O)OC
# C=C(Cl)CCl
# C=CC(=O)c1ccc2sc3ccccc3c(=O)c2c1
# C=C(C)C(=O)OC
# C=CCl
# C=COP(=O)(OCC)OCC
# C=CCl
# C=COP(=O)(Oc1ccccc1)Oc1ccccc1
# C=COC(C)=O
# C=COP(=O)(OCC)OCC
# C=COC(=O)CCl
# C=COP(=O)(OCC)OCC
# C=COC(=O)CCl
# C=COP(=O)(Oc1ccccc1)Oc1ccccc1
# C=COC(C)=O
# C=COP(=O)(OCC)OCC
# O=C1C=CC(=O)O1
# C=COP(=O)(OCC)OCC
# O=C1C=CC(=O)O1
# C=COP(=O)(Oc1ccccc1)Oc1ccccc1
# C=C(C)C(=O)OC
# C=Cn1c2ccccc2c2ccccc21
# C=C(C)C(=O)OC
# C=Cn1c2ccccc2c2ccccc21
# C=C(C)C
# C=COC(C)=O
# C=C(C)C
# C=CC#N
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# C=Cc1ccccc1
# C=Cc1ccc(OCC)cc1
# C=C(C)C(=O)OC
# C=Cc1ccc(OCC)cc1
# C=C(C)C(=O)OC
# C=CC(=O)OCCC(=O)O
# C=CC#N
# C=C
# C=C(C)C(=O)OC
# C=Cc1ccc(C)cc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=CCl
# C=CC
# C=C(C)C(=O)Oc1ccccc1C(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccccc1C(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccccc1C(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=COC(C)=O
# O=C1C=CC(=O)N1CO
# C=COC(C)=O
# O=C1C=CC(=O)N1CCO
# C=COC(C)=O
# O=C1C=CC(=O)N1c1ccc(O)cc1
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1CO
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1CCO
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1c1ccc(O)cc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCCC
# FC(F)=C(F)F
# C=C
# FC(F)=C(F)F
# C=C
# C=C(C)C(=O)OCCN(CC)CC
# C=C(C)C(=O)OCc1ccccc1
# C=C(C)C(=O)OCCN(CC)CC
# C=C(C)C(=O)OCc1ccccc1
# C=C(C)C(=O)OC
# C=CC(=O)C1CNCCO1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=COC(C)=O
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# C=COC(=O)c1ccccc1
# C=Cc1ccccc1
# CCCC[Sn+2]CCCC.O=C([O-])/C=C\C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCCC[Sn+2]CCCC.O=C([O-])/C=C\\C(=O)[O-].json'
# C=CC(=O)OCCCC
# CCCC[Sn+2]CCCC.O=C([O-])/C=C\C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCCC[Sn+2]CCCC.O=C([O-])/C=C\\C(=O)[O-].json'
# C=Cc1ccccc1
# C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC.json'
# C=CC(=O)OCCCC
# C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C/C(=C/C(=O)[O-])C(=O)[O-].CCCC[Sn+2]CCCC.json'
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CC#N
# C=C(C)C(=O)Oc1ccc2ccccc2c1
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCCCC
# C=CCOc1nc(OCC=C)nc(OCC=C)n1
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=COCC(C)C
# C=Cc1ccccc1
# C=COCC(C)C
# C=Cc1ccccc1
# C=C(C)C(=O)OCC
# C=C(C)C(=O)OCC=Cc1ccccc1
# C=C(C)C(=O)OCC
# C=C(C)C(=O)OCC=Cc1ccccc1
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OC
# C=CC(=O)OC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCC(C)O
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)O
# C=C(C)C(=O)C1CC(C)(C)NC(C)(C)C1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=Cc1ccccc1
# C=CC=CF
# C=Cc1ccccc1
# C=CC=CF
# C=CC#N
# C=CC=CF
# C=CC(=C)C
# C=CC=CF
# C=C(C)c1ccccc1
# C=CC=CF
# C=C(C)C(=O)OC
# C=CC=CF
# C=CCl
# C=C(C)C(=O)Oc1ccccc1C(=O)O
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCCN(C)C
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCCN(C)C
# C=C(C)C(=O)OCCO
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCCO
# C=CC(=O)OCCCC
# C=C(C)C(=O)OCCO
# C=C(F)C(N)=O
# C=C(C)C(=O)OC
# C=CC(=O)O
# C=CC(N)=O
# C=CC(=O)O
# ...
# C=CC=C
# C=C(C)C(=C)C
# C=CC=C
# C=Cc1ccccc1
# C=CC(=C)C
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OCCCCCCCCCCCC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OC
# Cc1ccc(C=C2CC(=O)N(c3ccccc3)C2=O)cc1
# C=C(C)C(=O)OC
# Cc1ccc(C=C2CC(=O)N(c3ccccc3)C2=O)cc1
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccccc2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccccc2)C1=O
# C=C(C)C(=O)OC
# C#Cc1ccccc1
# C=C(C)C(=O)OC(c1ccccc1)(c1ccccc1)c1ccccc1
# C=C(C)C(=O)OC(C)c1ccccc1
# C=C(C)C(=O)OC(c1ccccc1)(c1ccccc1)c1ccccc1
# C=C(C)C(=O)OC(C)c1ccccc1
# C=CC(N)=O
# C=CC(=O)O
# C=CC(N)=O
# C=CC(=O)O
# C=CC(N)=O
# C=C(C)C(=O)O
# C=CC(N)=O
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC(C)C(=O)NC1([N+](=O)[O-])C=CC(/C=C/c2ccccc2)=CC1.json'
# C=CC#N
# C[SH+]C=Cc1ccccc1.F[B-](F)(F)F
# C=CC(N)=O
# C[SH+]C=Cc1ccccc1.F[B-](F)(F)F
# C=C(C)C(=O)OC
# C=C(C)C(=O)[O-].CCCC[Sn+](CCCC)CCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(C)C(=O)[O-].CCCC[Sn+](CCCC)CCCC.json'
# C=CC=C
# C=CC(=O)OC
# C=CC=C
# C=CC(=O)OC
# C=COC(C)=O
# C=C
# C=C(C)C(=O)OCC
# C=C(C)C(=O)Oc1ccc(C(C)=O)cc1
# C=C(C)C(=O)OCC
# C=C(C)C(=O)Oc1ccc(C(C)=O)cc1
# C=CC(N)=O
# C=CC#N
# C=CC(N)=O
# C=CC#N
# C=CC(N)=O
# C=CC#N
# C=CC(N)=O
# C=CC#N
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccc(C#N)cc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccc(C#N)cc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccc(C#N)cc1
# C=CNC(=O)NCC
# C=COC(C)=O
# C=CNC(=O)NCC
# C=C(C)C(=O)OC
# C=CNC(=O)NCC
# C=Cc1ccccc1
# C=CC(=O)NC(C)(C)CS(=O)(=O)[O-].[Na+]
# C=COC(C)=O
# C=CC#N
# C=Cc1c(C)cc(C)cc1C
# C=Cc1ccc(Cl)cc1
# C=Cc1c(C)cc(C)cc1C
# C=C(C)C(=O)OCCO
# C=CC#N
# C=C(C)C(=O)OCCO
# C=CC#N
# C=C(C)C(=O)OCC(C)O
# C=CC#N
# C=C(C)C(=O)OCC(C)O
# C=CC#N
# C=C(C)C(=O)OCCO
# C=Cc1ccccc1
# C=C(C)C(=O)OCCO
# C=Cc1ccccc1
# C=C(C)C(=O)OCCO
# C=Cc1ccccc1
# C=C(C)C(=O)OCCO
# C=Cc1ccccc1
# C=CC#N
# C=C(C)C(=O)OC(C)C
# C=CC#N
# C=C(C)C(=O)OC(C)C
# C=C(C)C#N
# C=C(C)C(=O)OC(C)C
# C=C(C)C#N
# C=C(C)C(=O)OC(C)C
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)Oc1ccc(NC(=O)Cc2ccc(OC)cc2)cc1
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)Nc1ccc(OC(=O)Cc2ccc(OC)cc2)cc1
# C=C(C)C#N
# C=C(Cl)Cl
# C=C(C)C#N
# C=C(Cl)Cl
# C=CN1CCCC1=O
# C=CC(=O)OC1CCCCC1
# O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-].json'
# O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-].json'
# O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-].json'
# O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-].json'
# O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/O=C(O)c1cccc(C(=O)O)c1.[Cl-].[Cl-].json'
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=Cc1ccccc1
# C=C(C)C(=O)O
# C=CN1CCCC1=O
# C=COC(C)=O
# C=CN1CCCC1=O
# CCCCCCCCOC(=O)/C=C/C(=O)OCCCCCCCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(C)C(=O)O.C=C(C)C(=O)O.OCCOCCOCCOCCO.json'
# C=CCl
# C=COC(C)=O
# C=C(Cl)Cl
# C=C(C)C(=O)OCC
# O=C1C=CC(=O)O1
# C=CC(=O)OC[c-]1cccc1.[Fe+2].c1cc[cH-]c1
# C=C(C)C(=O)OCC(C)C
# C=CC(=C)Cl
# C=C(C)C(=O)OCC(O)CCl
# C=CC#N
# C=C(C)C(=O)OCC(O)CCl
# C=CC#N
# C=CC#N
# C=C(C)C(=O)[O-].[K+]
# C=C1CC(=O)OC1=O
# C=C(C)C(=O)OC(C)(C)C
# O=C1CCCCO1
# O=C1CCCCCO1
# O=C1CCCCO1
# O=C1CCCCCO1
# O=C1CCCCO1
# O=C1CCCCCO1
# O=C1CCCCO1
# O=C1CCCCCO1
# C=CC[N+](C)(C)CC=C.[Cl-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=CC[N+](C)(C)CC=C.[Cl-].json'
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC1CO1
# C=C(C)C(=O)OC
# C=CC(=O)OCC
# C=C(C)C(=O)OC
# C=CC(=O)OCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# C=CC(=O)OCCCC
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1
# C=Cc1ccccc1
# O=C1C=CC(=O)N1
# C=C(Cl)Cl
# O=C1C=CC(=O)N1
# C=C(C)C(=O)OC
# CC1=CC(=O)N(C)C1=O
# C=Cc1ccccc1
# CC1=CC(=O)N(C)C1=O
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(/C=C/C(=O)OCC)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(/C=C/C(=O)OCC)OCC.json'
# C=CC#N
# C=C(/C=C/C(=O)OCC)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(/C=C/C(=O)OCC)OCC.json'
# C=Cc1ccccc1
# C=C(/C=C/C#N)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/C=C(/C=C/C#N)OCC.json'
# C=CN1CCOC1=O
# C=Cc1ccccc1
# C=CN1CCCC1=O
# C=Cc1ccccc1
# C=CC(=C)O[Si](C)(C)C
# C=Cc1ccccc1
# C=CC(=C)O[Si](C)(C)C
# C=CC#N
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC(O)CO
# C=C(C)C(=O)OCCO
# C=C(C)C(=O)OCC(O)CO
# C=C(C)C(=O)OCCO
# C=COC(C)=O
# C=CC(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=Cc1ccccc1
# C=CC(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=C(C)C(=O)OC
# C=CC(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=COC(C)=O
# C=C(C)C(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=Cc1ccccc1
# C=C(C)C(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=C(C)C(=O)OC
# C=C(C)C(=O)NC[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO
# C=CC#N
# C=CC=C
# C=CC#N
# C=CC=C
# C=C(C)C(=O)OC
# C=C(Cl)Cl
# C=C(C)C(=O)OCc1ccccc1
# C=C(Cl)Cl
# C=C(C)C(=O)Cl
# C=C(Cl)Cl
# C=COC(C)=O
# C=C(Cl)Cl
# C=CC(=O)OC
# C=Cc1ccccc1
# C=CC(=O)OC
# C=Cc1ccccc1
# C=CN1C(=O)CCC1=O
# C=COC(C)=S
# C=CN1C(=O)c2ccccc2C1=O
# C=COC(C)=S
# C=Cn1c2ccccc2c2ccccc21
# C=COC(C)=S
# Cc1ccc(N2C(=O)C=CC2=O)cc1
# C=C(C)C(=O)OC
# C=CC(C)=O
# C=CC#N
# C=CC(C)=O
# C=CC#N
# C=Cc1ccc(OC)cc1
# C=C(C)C(=O)OC
# C=CN1CCCC1=O
# C=C(C)C(=O)OCC1CO1
# C=CN1CCCC1=O
# C=C(C)C(=O)OCC1CO1
# C=CN1CCCC1=O
# C=C(C)C(=O)NCCCN(C)C
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# COC(=O)/C=C\C(=O)[O-]
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)[O-].json'
# N#C/C=C/C#N
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/N#C/C=C/C#N.json'
# N#C/C=C\C#N
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/N#C/C=C\\C#N.json'
# Cl/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C/Cl.json'
# Cl/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C\\Cl.json'
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# CCOC(=O)/C=C/C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C/C(=O)OCC.json'
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# Cl/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C/Cl.json'
# Cl/C=C\Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C\\Cl.json'
# C(=Cc1ccccc1)c1ccccc1
# O=C1C=CC(=O)O1
# Cl/C=C/Cl
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/Cl/C=C/Cl.json'
# C=C1CC(=O)N(c2ccc(Cl)cc2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccc(Cl)cc2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2cccc(Cl)c2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccccc2Cl)C1=O
# C=C(C)C(=O)OC
# C=COCCCl
# C=COCC(C)C
# C=COCCCl
# C=COCCCCCCCCCCCCCCCCCC
# C=COCCCl
# C=C(C)c1ccccc1
# C=COCCCl
# C=C(C)c1ccc(C)cc1
# C=COCCCl
# C=C(C)c1ccc(OC)cc1
# C=COC(C)=O
# C=CC(=O)OCCCCCCCCCCCCCCCCCCCCCC
# C=COC(C)=O
# C=CC(=O)OCCCCCCCCCCCCCCCCCCCCCC
# C=C(C)N=C=O
# C=CC(=O)OC
# C=C(C)N=C=O
# C=Cc1ccccc1
# C=COC(C)=O
# O=c1occo1
# C=CCl
# O=c1occo1
# C=C(C)C(=O)OC
# O=c1occo1
# C=CN1CCCC1=O
# O=c1occo1
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2ccc(OC)c(Cl)c2)C1=O
# C=C(C)C(=O)OC
# C=C1CC(=O)N(c2cc(Cl)ccc2OC)C1=O
# C=CC(=O)OCCCC
# C=CC(N)=O
# C=CC(=O)OCCCC
# C=CC(N)=O
# C=CC(=O)OCCCC
# C=CC(N)=O
# COC(=O)C=C(CC(=O)OC)C(=O)OC
# C=CC#N
# C=C(C)C(=O)OC
# C=C(CO)C(=O)OCC
# C=C(C)C(=O)OC
# C=C(CO)C(=O)OCC
# C=CCl
# C=Cc1ccccc1
# C=COC(C)=O
# C=CCl
# CCOC(=O)/C=C\C(=O)OCC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CCOC(=O)/C=C\\C(=O)OCC.json'
# COC(=O)/C=C\C(=O)OC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/COC(=O)/C=C\\C(=O)OC.json'
# C=C(C)C(=O)OC(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(c1ccccc1)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(c1ccccc1)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC(C)(C)C
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# Cc1ccc(N(C)C)cc1N1C(=O)C=CC1=O
# C=C(C)C(=O)OC
# Cc1ccc(N(C)C)cc1N1C(=O)C=CC1=O
# O=C1C=CC(=O)N1c1ccccc1Cl
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Cl
# C=CC#N
# O=C1C=CC(=O)N1c1ccc(Cl)cc1
# C=CC#N
# O=C1C=CC(=O)N1c1ccc(Cl)cc1
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Br
# C=CC#N
# O=C1C=CC(=O)N1c1ccccc1Br
# C=CC#N
# CCCCCCCCCCCCCCCCCCN1C(=O)C=CC1=O
# C=CC#N
# CCCCCCCCCCCCCCCCCCN1C(=O)C=CC1=O
# C=CC#N
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# O=C1C=CC(=O)O1
# C=Cc1ccccc1
# C=Cc1cccc2c1[nH]c1ccccc12
# C=Cc1ccccc1
# C=Cc1cccc2c1[nH]c1ccccc12
# C=C(C)C(=O)OC
# C=C(Cl)CCl
# C=Cc1ccccc1
# C=C(Cl)CCl
# C=C(C)C(=O)OC
# C=C(C)C(=O)OC
# C=CC(=O)c1ccc2sc3ccccc3c(=O)c2c1
# C=COP(=O)(OCC)OCC
# C=CCl
# C=COP(=O)(Oc1ccccc1)Oc1ccccc1
# C=CCl
# C=COP(=O)(OCC)OCC
# C=COC(C)=O
# C=COP(=O)(OCC)OCC
# C=COC(=O)CCl
# C=COP(=O)(Oc1ccccc1)Oc1ccccc1
# C=COC(=O)CCl
# C=COP(=O)(OCC)OCC
# C=COC(C)=O
# C=COP(=O)(OCC)OCC
# O=C1C=CC(=O)O1
# C=COP(=O)(Oc1ccccc1)Oc1ccccc1
# O=C1C=CC(=O)O1
# C=Cn1c2ccccc2c2ccccc21
# C=C(C)C(=O)OC
# C=Cn1c2ccccc2c2ccccc21
# C=C(C)C(=O)OC
# C=COC(C)=O
# C=C(C)C
# C=CC#N
# C=C(C)C
# C=COC(C)=O
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# C=CC#N
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# C=COC(C)=O
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# C=CC#N
# CC=CC
# File not found: [Errno 2] No such file or directory: '../copol_prediction/output/molecule_properties/CC=CC.json'
# C=Cc1ccc(OCC)cc1
# C=Cc1ccccc1
# C=Cc1ccc(OCC)cc1
# C=C(C)C(=O)OC
# C=CC(=O)OCCC(=O)O
# C=C(C)C(=O)OC
# C=C
# C=CC#N
# C=Cc1ccc(C)cc1
# C=C(C)C(=O)OC
# C=Cc1ccccc1
# C=C(C)C(=O)OC
# C=CC
# C=CCl
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccccc1C(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccccc1C(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Oc1ccccc1C(=O)c1ccccc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(C(=O)O)c(O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# C=C(C)C(=O)OC
# C=C(C)C(=O)Nc1ccc(O)c(C(=O)O)c1
# O=C1C=CC(=O)N1CO
# C=COC(C)=O
# O=C1C=CC(=O)N1CCO
# C=COC(C)=O
# O=C1C=CC(=O)N1c1ccc(O)cc1
# C=COC(C)=O
# O=C1C=CC(=O)N1CO
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1CCO
# C=C(C)C(=O)OC
# O=C1C=CC(=O)N1c1ccc(O)cc1
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCC
# C=C(C)C(=O)OC
# C=C(C)C(=O)OCCCC
# C=C(C)C(=O)OC
# C=C
# FC(F)=C(F)F
# C=C
# FC(F)=C(F)F

# %%
len(df_filtered)
# Out:
# 880

# %%
df_filtered[df_filtered['reaction_method']=='bulk']
# Out:
#                           _id  \
# 13   67ee494d8a67c60235f7d999
# 14   67ee494d8a67c60235f7d99b
# 15   67ee494d8a67c60235f7d99d
# 16   67ee494d8a67c60235f7d99f
# 17   67ee494d8a67c60235f7d9a1
# ..                        ...
# 838  67ee82588a67c60235f7e450
# 839  67ee82638a67c60235f7e452
# 840  67ee82638a67c60235f7e453
# 876  67ee85448a67c60235f7e4c1
# 877  67ee85448a67c60235f7e4c2
#
#                                                 source  \
# 13          https://doi.org/10.1002/app.1991.070420522
# 14          https://doi.org/10.1002/app.1991.070420522
# 15          https://doi.org/10.1002/app.1991.070420522
# 16          https://doi.org/10.1002/app.1991.070420522
# 17          https://doi.org/10.1002/app.1991.070420522
# ..                                                 ...
# 838  Journal of Polymer Science Vol. IV, pp. 215-21...
# 839  Journal of Polymer Science Vol. IV, pp. 215-21...
# 840  Journal of Polymer Science Vol. IV, pp. 215-21...
# 876                  https://doi.org/10.1002/app.30961
# 877                  https://doi.org/10.1002/app.30961
#
#                                               PDF_name  \
# 13   Copolymerization of Alkyl Methacrylates with T...
# 14   Copolymerization of Alkyl Methacrylates with T...
# 15   Copolymerization of Alkyl Methacrylates with T...
# 16   Copolymerization of Alkyl Methacrylates with T...
# 17   Copolymerization of Alkyl Methacrylates with T...
# ..                                                 ...
# 838  copolymerization_of_some_further_monomer_pairs...
# 839  copolymerization_of_some_further_monomer_pairs...
# 840  copolymerization_of_some_further_monomer_pairs...
# 876  Studies on Binary Copolymerization and Glass T...
# 877  Studies on Binary Copolymerization and Glass T...
#
#                    original_filename             monomer1  \
# 13   10.1002_app.1991.070420601.json  Propyl Methacrylate
# 14   10.1002_app.1991.070420601.json  Pentyl Methacrylate
# 15   10.1002_app.1991.070420601.json   Hexyl Methacrylate
# 16   10.1002_app.1991.070420601.json  Heptyl Methacrylate
# 17   10.1002_app.1991.070420601.json   Octyl Methacrylate
# ..                               ...                  ...
# 838  10.1002_pol.1949.120040209.json  Methyl Methacrylate
# 839  10.1002_pol.1949.120040209.json              Styrene
# 840  10.1002_pol.1949.120040209.json  Methyl Methacrylate
# 876           10.1002_app.30961.json  Methyl Methacrylate
# 877           10.1002_app.30961.json  Methyl Methacrylate
#
#                    monomer2  reaction_index  condition_index  \
# 13       Triallyl Cyanurate               0                0
# 14       Triallyl Cyanurate               1                0
# 15       Triallyl Cyanurate               2                0
# 16       Triallyl Cyanurate               3                0
# 17       Triallyl Cyanurate               4                0
# ..                      ...             ...              ...
# 838         Vinyl Carbazole               1                0
# 839  1,2-Dichloro-2-propene               2                0
# 840  1,2-Dichloro-2-propene               3                0
# 876      Ethyl Methacrylate               0                0
# 877    n-Butyl Methacrylate               1                0
#
#                                               filename  \
# 13                       app.1991.070420522_r0_c0.json
# 14                       app.1991.070420522_r1_c0.json
# 15                       app.1991.070420522_r2_c0.json
# 16                       app.1991.070420522_r3_c0.json
# 17                       app.1991.070420522_r4_c0.json
# ..                                                 ...
# 838  Journal of Polymer Science Vol. IV, pp. 215-21...
# 839  Journal of Polymer Science Vol. IV, pp. 215-21...
# 840  Journal of Polymer Science Vol. IV, pp. 215-21...
# 876                               app.30961_r0_c0.json
# 877                               app.30961_r1_c0.json
#
#                      created_at  ... fukui_radical_min_2 fukui_radical_max_2  \
# 13   2025-04-03T08:39:41.974000  ...           -0.010430            0.060293
# 14   2025-04-03T08:39:41.979000  ...           -0.010430            0.060293
# 15   2025-04-03T08:39:41.984000  ...           -0.010430            0.060293
# 16   2025-04-03T08:39:41.992000  ...           -0.010430            0.060293
# 17   2025-04-03T08:39:41.996000  ...           -0.010430            0.060293
# ..                          ...  ...                 ...                 ...
# 838  2025-04-03T12:43:04.184000  ...            0.012596            0.063445
# 839  2025-04-03T12:43:04.192000  ...           -0.035264            0.282111
# 840  2025-04-03T12:43:15.161000  ...           -0.035264            0.282111
# 876  2025-04-03T12:55:32.335000  ...           -0.028653            0.160009
# 877  2025-04-03T12:55:32.340000  ...           -0.027240            0.150708
#
#     fukui_radical_mean_2 dipole_x_2  dipole_y_2 dipole_z_2 temperature  \
# 13              0.030303   0.002356    0.000599  -0.084954        60.0
# 14              0.030303   0.002356    0.000599  -0.084954        60.0
# 15              0.030303   0.002356    0.000599  -0.084954        60.0
# 16              0.030303   0.002356    0.000599  -0.084954        60.0
# 17              0.030303   0.002356    0.000599  -0.084954        60.0
# ..                   ...        ...         ...        ...         ...
# 838             0.038462  -0.113567    0.614863   0.068897        70.0
# 839             0.111111  -0.373286    0.006694   0.833315        70.0
# 840             0.111111  -0.373286    0.006694   0.833315        70.0
# 876             0.055556   0.238999    0.732208   0.412289        60.0
# 877             0.041667   0.178675    0.245567  -0.839094        60.0
#
#       solvent  polymerization_method  solvent_logp
# 13   c1ccccc1           free radical        1.6866
# 14   c1ccccc1           free radical        1.6866
# 15   c1ccccc1           free radical        1.6866
# 16   c1ccccc1           free radical        1.6866
# 17   c1ccccc1           free radical        1.6866
# ..        ...                    ...           ...
# 838  c1ccccc1           free radical        1.6866
# 839  c1ccccc1           free radical        1.6866
# 840  c1ccccc1           free radical        1.6866
# 876         O           free radical       -0.8247
# 877         O           free radical       -0.8247
#
# [107 rows x 80 columns]

# %% [markdown]
# ## Modeling

# %%
method_mapping = {
    'bulk': 0,
    'Bulk': 0,
    'solvent': 1,
    'Solvent': 1,
    'emulsion': 2,
    'suspension': 3,
    'photopolymerization': 10,
    'None': 20
}

calculation_method_mapping = {
    'Kelen-Tudor': 0,
    'Fineman-Ross': 1,
    'Fineman and Ross': 1,
    'Fineman Ross method': 1,
    'fundamental equation of copolymerisation': 2,
    'Mayo and Lewis': 3,
    'Mayo-Lewis differential method': 3,
    'Mayo and Lewis method': 3,
    'Mayo and Lewis intersection method': 3,
    'Intersection method': 3,
    'intersection method of Mayo and Lewis': 3,
    'Joshi-Joshi': 4,
    'Schwan and Price': 5,
    'Alfrey-Price': 6,
    'Alfrey and Goldfinger': 6,
    'regression analysis': 7,
    'nonlinear least squares technique': 7,
    'non-linear regression': 7,
    'nonlinear least squares': 7,
    'nonlinear least squares analysis': 7,
    'nonlinear least squares procedure': 7,
    'approximations successives': 7,
    'graphical solution of the copolymerization equation': 8,
    'graphical method of intersections': 8,
    'graphical evaluation': 8,
    'graphical': 8,
    'graphic method': 8,
    'graphic solution': 8,
    'logarithm plot': 9,
    'polarization': 10,
    'Nuclear magnetic resonance spectroscopy': 11,
    'NMR spectroscopy': 11,
    'NMR analysis': 11,
    'carbon elemental analyses': 12,
    'nitrogen analyses': 13,
    'Ghosh-Palit': 14,
    'curve fitting': 15,
    'curve-fitting technique': 15,
    'curve-fitting': 15,
    'Multiparameter correlation equation': 16,
    'Yserielve-Brokhina-Roskin': 17,
    'Yezrielev method': 17,
    'Ezrievlev and co-workers': 17,
    'Shtraikhman approach': 18,
    'differential form of the copolymer equation': 19,
    'penultimate model': 20,
    'penultimate mu model': 20,
    'Alfrey-Price equation': 21,
    'assumed': 22,
    'Optimizer': 23,
    'Barb': 24,
    'previous paper': 30,
    'not provided': 30,
    'not specified': 30,
    'EVM Program': 27,
    'Tidwell-Mortimer': 28,
    'Grant': 29,
    'null': 30,
    'None': 30
}

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer

def map_method(X, column, mapping):
    return X[column].map(mapping).values.reshape(-1, 1)

# Define the features
numerical_features = ['reaction_temperature', 'ip_corrected_1', 'ea_1', 'homo_1', 'lumo_1',
                      'global_electrophilicity_1', 'global_nucleophilicity_1',
                      'best_conformer_energy_1', 'charges_min_1', 'charges_max_1',
                      'charges_mean_1', 'fukui_electrophilicity_min_1',
                      'fukui_electrophilicity_max_1', 'fukui_electrophilicity_mean_1',
                      'fukui_nucleophilicity_min_1', 'fukui_nucleophilicity_max_1',
                      'fukui_nucleophilicity_mean_1', 'fukui_radical_min_1',
                      'fukui_radical_max_1', 'fukui_radical_mean_1', 'dipole_x_1',
                      'dipole_y_1', 'dipole_z_1',  'ip_corrected_2', 'ea_2', 'homo_2',
                      'lumo_2', 'global_electrophilicity_2', 'global_nucleophilicity_2',  
                      'charges_min_2', 'charges_max_2', 'charges_mean_2', 
                      'fukui_electrophilicity_min_2', 'fukui_electrophilicity_max_2', 
                      'fukui_electrophilicity_mean_2', 'fukui_nucleophilicity_min_2', 
                      'fukui_nucleophilicity_max_2', 'fukui_nucleophilicity_mean_2', 
                      'fukui_radical_min_2', 'fukui_radical_max_2', 'fukui_radical_mean_2', 
                      'dipole_x_2', 'dipole_y_2', 'dipole_z_2', 'solvent_logp']

categorical_features = ['reaction_polymerization_type']

# Define the transformer
transformer = ColumnTransformer([
    ('numerical', StandardScaler(), numerical_features),
    
])

# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

# Create the target variable for both DataFrames
df_filtered['r1r2'] = df_filtered['r1'] * df_filtered['r2']
df_filtered_flipped['r1r2'] = df_filtered_flipped['r1'] * df_filtered_flipped['r2']

# Combine the two DataFrames
combined_df = pd.concat([df_filtered])

# Fit and transform the features using the transformer
X_combined = transformer.fit_transform(combined_df)

# Create a DataFrame with the transformed features
#categorical_feature_names = transformer.named_transformers_['categorical'].get_feature_names_out(categorical_features)

feature_names = numerical_features 
                #['calculation_method_encoded', 'polymerization_method_encoded']

X_combined_df = pd.DataFrame(X_combined, columns=feature_names)

# Append the target variable to the DataFrame
X_combined_df['r1r2'] = combined_df['r1r2'].values

# Calculate Spearman correlation
correlation_results = {}
for column in X_combined_df.columns:
    if column != 'r1r2':
        corr, _ = spearmanr(X_combined_df[column], X_combined_df['r1r2'])
        correlation_results[column] = corr

# Convert to DataFrame for easy handling
correlation_df = pd.DataFrame.from_dict(correlation_results, orient='index', columns=['Spearman Correlation'])

# Sort by absolute correlation value
correlation_df['abs_corr'] = correlation_df['Spearman Correlation'].abs()
correlation_df.sort_values('abs_corr', ascending=False, inplace=True)

# Print correlation values
print(correlation_df)

# Plot the correlations
plt.figure()
correlation_df['Spearman Correlation'].plot(kind='bar')
plt.title('Spearman Correlation of Features with r1r2 (Combined Data)')
plt.ylabel('Spearman Correlation')
plt.xlabel('Features')
plt.xticks(rotation=90)

plt.savefig('spearman_all.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
#                                Spearman Correlation  abs_corr
# charges_min_2                             -0.251280  0.251280
# fukui_electrophilicity_min_2              -0.223970  0.223970
# fukui_radical_min_2                       -0.196559  0.196559
# dipole_z_2                                 0.187227  0.187227
# fukui_nucleophilicity_min_2               -0.182138  0.182138
# charges_max_2                              0.137491  0.137491
# charges_min_1                             -0.127197  0.127197
# fukui_electrophilicity_max_2               0.094912  0.094912
# solvent_logp                              -0.094194  0.094194
# fukui_radical_mean_2                      -0.090924  0.090924
# fukui_nucleophilicity_mean_2              -0.090704  0.090704
# fukui_electrophilicity_mean_2             -0.086802  0.086802
# lumo_1                                    -0.065490  0.065490
# best_conformer_energy_1                   -0.064876  0.064876
# dipole_x_2                                 0.062388  0.062388
# fukui_electrophilicity_max_1               0.061828  0.061828
# charges_max_1                              0.060860  0.060860
# dipole_z_1                                 0.054604  0.054604
# charges_mean_1                             0.052109  0.052109
# fukui_electrophilicity_mean_1             -0.050684  0.050684
# fukui_nucleophilicity_mean_1              -0.050493  0.050493
# fukui_radical_mean_1                      -0.049955  0.049955
# dipole_y_1                                 0.046776  0.046776
# fukui_radical_max_2                        0.045733  0.045733
# fukui_nucleophilicity_max_2                0.041094  0.041094
# dipole_y_2                                 0.039556  0.039556
# ip_corrected_2                            -0.036150  0.036150
# global_nucleophilicity_2                   0.036150  0.036150
# charges_mean_2                            -0.029934  0.029934
# global_electrophilicity_1                  0.020264  0.020264
# lumo_2                                    -0.018237  0.018237
# homo_1                                    -0.017826  0.017826
# fukui_radical_max_1                        0.013974  0.013974
# reaction_temperature                      -0.013505  0.013505
# global_nucleophilicity_1                   0.013469  0.013469
# ip_corrected_1                            -0.013469  0.013469
# homo_2                                     0.011975  0.011975
# fukui_nucleophilicity_max_1                0.011662  0.011662
# ea_1                                       0.009972  0.009972
# ea_2                                      -0.009303  0.009303
# fukui_nucleophilicity_min_1               -0.006221  0.006221
# dipole_x_1                                -0.004459  0.004459
# global_electrophilicity_2                 -0.002511  0.002511
# fukui_radical_min_1                        0.001144  0.001144
# fukui_electrophilicity_min_1               0.000750  0.000750

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import PowerTransformer
from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
import shap

# Define the power transformer for the label
pt = PowerTransformer(method='yeo-johnson')

# Define the parameter grid for RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 500, 1000, 5000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': np.logspace(-3, 0, 10),
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'min_child_weight': [1, 3, 5],
    'gamma': [0, 0.1, 0.2],
    'reg_alpha': np.linspace(0, 1, 10),
    'reg_lambda': np.linspace(0, 1, 10)
}

# Implement K-Fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
fold_scores = []

all_y_true = []
all_y_pred = []
all_y_train_true = []
all_y_train_pred = []

for fold, (train_idx, test_idx) in enumerate(kf.split(df_filtered), 1):
    print(f"Fold {fold}")
    
    # Split the data
    train = df_filtered.iloc[train_idx]
    test = df_filtered.iloc[test_idx]
    
    #train_flipped = df_filtered_flipped.iloc[train_idx]
    #test_flipped = df_filtered_flipped.iloc[test_idx]
    train = pd.concat([train])
    test = pd.concat([test])
    
    # Create the target variable
    train['r1r2'] = train['r1'] * train['r2']
    test['r1r2'] = test['r1'] * test['r2']
    
    # Fit and transform the features
    X_train = transformer.fit_transform(train)
    X_test = transformer.transform(test)
    
    # Transform the label
    y_train = pt.fit_transform(train['r1r2'].values.reshape(-1, 1)).ravel()
    y_test = pt.transform(test['r1r2'].values.reshape(-1, 1)).ravel()
    
    # Define the model
    model = XGBRegressor(random_state=42)
    
    # Perform RandomizedSearchCV
    random_search = RandomizedSearchCV(model, param_distributions=param_grid, 
                                       n_iter=100, cv=3, verbose=1, 
                                       random_state=42, n_jobs=-1)
    random_search.fit(X_train, y_train, 
                    #   early_stopping_rounds=10, 
                      eval_set=[(X_test, y_test)],
                      verbose=False)
    
    # Get the best model
    best_model = random_search.best_estimator_
    
    explainer = shap.Explainer(best_model)
    shap_values = explainer(X_train)
    shap.plots.beeswarm(shap_values)
    
    # Make predictions
    y_pred_train = best_model.predict(X_train)
    y_pred_test = best_model.predict(X_test)
    
    # Store true and predicted values for train
    all_y_train_true.extend(y_train)  # Appending the true values (train)
    all_y_train_pred.extend(y_pred_train)  # Appending the predicted values (train)
    
    # Store true and predicted values for test
    all_y_true.extend(y_test)  # Appending the true values (test)
    all_y_pred.extend(y_pred_test)  # Appending the predicted values (test)
    
    
    # Calculate metrics
    mse_train = mean_squared_error(y_train, y_pred_train)
    r2_train = r2_score(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    r2_test = r2_score(y_test, y_pred_test)
    
    print(f"Train MSE: {mse_train:.4f}, Train R2: {r2_train:.4f}")
    print(f"Test MSE: {mse_test:.4f}, Test R2: {r2_test:.4f}")
    print(f"Best Hyperparameters for Fold {fold}: {random_search.best_params_}")

    
    fold_scores.append((r2_train, r2_test))

# Calculate average scores across all folds
avg_train_r2 = np.mean([score[0] for score in fold_scores])
avg_test_r2 = np.mean([score[1] for score in fold_scores])

print(f"\nAverage Train R2: {avg_train_r2:.4f}")
print(f"Average Test R2: {avg_test_r2:.4f}")
# Out:
# Fold 1
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /Users/maraw/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Train MSE: 0.9308, Train R2: 0.0692
# Test MSE: 0.2305, Test R2: 0.0211
# Best Hyperparameters for Fold 1: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 2
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9431, Train R2: 0.0569
# Test MSE: 0.3294, Test R2: 0.1248
# Best Hyperparameters for Fold 2: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 3
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9411, Train R2: 0.0589
# Test MSE: 0.1571, Test R2: 0.1723
# Best Hyperparameters for Fold 3: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 4
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9280, Train R2: 0.0720
# Test MSE: 0.0265, Test R2: 0.0350
# Best Hyperparameters for Fold 4: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 5
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9347, Train R2: 0.0653
# Test MSE: 0.0121, Test R2: -0.2136
# Best Hyperparameters for Fold 5: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 6
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9217, Train R2: 0.0783
# Test MSE: 67.9339, Test R2: 0.0023
# Best Hyperparameters for Fold 6: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 7
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9319, Train R2: 0.0681
# Test MSE: 0.0135, Test R2: -0.1252
# Best Hyperparameters for Fold 7: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 8
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9441, Train R2: 0.0559
# Test MSE: 2.1086, Test R2: 0.0032
# Best Hyperparameters for Fold 8: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 9
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9393, Train R2: 0.0607
# Test MSE: 1.1227, Test R2: 0.0019
# Best Hyperparameters for Fold 9: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
# Fold 10
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# Train MSE: 0.9256, Train R2: 0.0744
# Test MSE: 2.4645, Test R2: -0.0088
# Best Hyperparameters for Fold 10: {'subsample': 0.6, 'reg_lambda': 0.0, 'reg_alpha': 0.6666666666666666, 'n_estimators': 100, 'min_child_weight': 3, 'max_depth': 9, 'learning_rate': 0.001, 'gamma': 0.2, 'colsample_bytree': 0.8}
#
# Average Train R2: 0.0660
# Average Test R2: 0.0013

# %%
df_filtered.to_json("data_old.json", orient="records", indent=4)

# %%
import matplotlib.pyplot as plt

# Plot true vs predicted values for all data
plt.figure(figsize=(8, 8))
plt.scatter(all_y_train_true, all_y_train_pred, alpha=0.5, label='Train Data')
plt.scatter(all_y_true, all_y_pred, alpha=0.5, label='Test Data', color='orange')
plt.plot([min(all_y_true + all_y_train_true), max(all_y_true + all_y_train_true)],
         [min(all_y_true + all_y_train_true), max(all_y_true + all_y_train_true)],
         color='red', linestyle='--')  # Line y=x
plt.xlabel('True Values')
plt.ylabel('Predicted Values')
plt.title('True vs Predicted Values (All Data)')
plt.legend()
plt.savefig('pred_all_xgboost.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Random selection of 200 train datapoints
train_indices = np.random.choice(len(all_y_train_true), 200, replace=False)
selected_y_train_true = np.array(all_y_train_true)[train_indices]
selected_y_train_pred = np.array(all_y_train_pred)[train_indices]

# Random selection of 100 test datapoints
test_indices = np.random.choice(len(all_y_true), 100, replace=False)
selected_y_true = np.array(all_y_true)[test_indices]
selected_y_pred = np.array(all_y_pred)[test_indices]

selected_y_train_true_inv = pt.inverse_transform(np.array(selected_y_train_true).reshape(-1, 1)).ravel()
selected_y_train_pred_inv = pt.inverse_transform(np.array(selected_y_train_pred).reshape(-1, 1)).ravel()

selected_y_true_inv = pt.inverse_transform(np.array(selected_y_true).reshape(-1, 1)).ravel()
selected_y_pred_inv = pt.inverse_transform(np.array(selected_y_pred).reshape(-1, 1)).ravel()

plt.figure(figsize=(8, 8))

plt.style.use('../data_extraction/plots_and_figures/lamalab.mplstyle')

plt.scatter(selected_y_train_true_inv, selected_y_train_pred_inv, alpha=0.7, label='Train Data', color='#661124')
plt.plot([min(selected_y_train_true_inv), max(selected_y_train_true_inv)], 
         [min(selected_y_train_true_inv), max(selected_y_train_true_inv)], 
         color='grey', linestyle='--')  # Linie y=x

plt.scatter(selected_y_true_inv, selected_y_pred_inv, alpha=0.7, label='Test Data', color='#194A81')
plt.xlabel(r'True $r_{\text{product}}$', fontsize=16)
plt.ylabel(r'Predicted $r_{\text{product}}$', fontsize=16)
plt.xlim(-0.1, 2)
plt.ylim((-0.1,2))
plt.legend(fontsize=12)

plt.savefig('pred_200_XGBoost.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer, PowerTransformer
from sklearn.model_selection import KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from xgboost import XGBRegressor
import shap

# Define molecular features (numerical only)
numerical_features = ['ip_corrected_1', 'ea_1', 'homo_1', 'lumo_1',
                      'global_electrophilicity_1', 'global_nucleophilicity_1',
                      'best_conformer_energy_1', 'charges_min_1', 'charges_max_1',
                      'charges_mean_1', 'fukui_electrophilicity_min_1',
                      'fukui_electrophilicity_max_1', 'fukui_electrophilicity_mean_1',
                      'fukui_nucleophilicity_min_1', 'fukui_nucleophilicity_max_1',
                      'fukui_nucleophilicity_mean_1', 'fukui_radical_min_1',
                      'fukui_radical_max_1', 'fukui_radical_mean_1', 'dipole_x_1',
                      'dipole_y_1', 'dipole_z_1',  'ip_corrected_2', 'ea_2', 'homo_2',
                      'lumo_2', 'global_electrophilicity_2', 'global_nucleophilicity_2',  
                      'charges_min_2', 'charges_max_2', 'charges_mean_2', 
                      'fukui_electrophilicity_min_2', 'fukui_electrophilicity_max_2', 
                      'fukui_electrophilicity_mean_2', 'fukui_nucleophilicity_min_2', 
                      'fukui_nucleophilicity_max_2', 'fukui_nucleophilicity_mean_2', 
                      'fukui_radical_min_2', 'fukui_radical_max_2', 'fukui_radical_mean_2', 
                      'dipole_x_2', 'dipole_y_2', 'dipole_z_2']

# Define transformer for molecular features only
transformer_molecular = ColumnTransformer([
    ('numerical', StandardScaler(), numerical_features)
])

# Define transformer for all features (assuming the other transformer is already defined as 'transformer_all')
# transformer_all = (definition for transformer_all, if required)

# Define the power transformer for the label
pt = PowerTransformer(method='yeo-johnson')

# Define the parameter grid for RandomizedSearchCV
param_grid = {
    'n_estimators': [100, 500, 1000, 5000],
    'max_depth': [3, 5, 7, 9],
    'learning_rate': np.logspace(-3, 0, 10),
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0],
    'min_child_weight': [1, 3, 5],
    'gamma': [0, 0.1, 0.2],
    'reg_alpha': np.linspace(0, 1, 10),
    'reg_lambda': np.linspace(0, 1, 10)
}

# Implement K-Fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
fold_scores = []

all_y_true = []
all_y_pred = []
all_y_train_true = []
all_y_train_pred = []

for fold, (train_idx, test_idx) in enumerate(kf.split(df_filtered), 1):
    print(f"Fold {fold}")
    
    # Split the data
    train = df_filtered.iloc[train_idx]
    test = df_filtered.iloc[test_idx]
    
    train_flipped = df_filtered_flipped.iloc[train_idx]
    test_flipped = df_filtered_flipped.iloc[test_idx]
    train = pd.concat([train, train_flipped])
    test = pd.concat([test, test_flipped])
    
    # Create the target variable
    train['r1r2'] = train['r1'] * train['r2']
    test['r1r2'] = test['r1'] * test['r2']
    
    # Fit and transform the features using only molecular features
    X_train = transformer_molecular.fit_transform(train)
    X_test = transformer_molecular.transform(test)
    
    # Transform the label
    y_train = pt.fit_transform(train['r1r2'].values.reshape(-1, 1)).ravel()
    y_test = pt.transform(test['r1r2'].values.reshape(-1, 1)).ravel()
    
    # Define the model
    model = XGBRegressor(random_state=42)
    
    # Perform RandomizedSearchCV
    random_search = RandomizedSearchCV(model, param_distributions=param_grid, 
                                       n_iter=100, cv=3, verbose=1, 
                                       random_state=42, n_jobs=-1)
    random_search.fit(X_train, y_train, 
                    #   early_stopping_rounds=10, 
                      eval_set=[(X_test, y_test)],
                      verbose=False)
    
    # Get the best model
    best_model = random_search.best_estimator_
    
    explainer = shap.Explainer(best_model)
    shap_values = explainer(X_train)
    shap.plots.beeswarm(shap_values)
    
    # Make predictions
    y_pred_train = best_model.predict(X_train)
    y_pred_test = best_model.predict(X_test)
    
    # Store true and predicted values for train
    all_y_train_true.extend(y_train)  # Appending the true values (train)
    all_y_train_pred.extend(y_pred_train)  # Appending the predicted values (train)
    
    # Store true and predicted values for test
    all_y_true.extend(y_test)  # Appending the true values (test)
    all_y_pred.extend(y_pred_test)  # Appending the predicted values (test)
    
    
    # Calculate metrics
    mse_train = mean_squared_error(y_train, y_pred_train)
    r2_train = r2_score(y_train, y_pred_train)
    mse_test = mean_squared_error(y_test, y_pred_test)
    r2_test = r2_score(y_test, y_pred_test)
    
    print(f"Train MSE: {mse_train:.4f}, Train R2: {r2_train:.4f}")
    print(f"Test MSE: {mse_test:.4f}, Test R2: {r2_test:.4f}")
    print(f"Best Hyperparameters for Fold {fold}: {random_search.best_params_}")

    
    fold_scores.append((r2_train, r2_test))

# Calculate average scores across all folds
avg_train_r2 = np.mean([score[0] for score in fold_scores])
avg_test_r2 = np.mean([score[1] for score in fold_scores])

print(f"\nAverage Train R2: {avg_train_r2:.4f}")
print(f"Average Test R2: {avg_test_r2:.4f}")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Random selection of 200 train datapoints
train_indices = np.random.choice(len(all_y_train_true), 200, replace=False)
selected_y_train_true = np.array(all_y_train_true)[train_indices]
selected_y_train_pred = np.array(all_y_train_pred)[train_indices]

# Random selection of 100 test datapoints
test_indices = np.random.choice(len(all_y_true), 100, replace=False)
selected_y_true = np.array(all_y_true)[test_indices]
selected_y_pred = np.array(all_y_pred)[test_indices]

selected_y_train_true_inv = pt.inverse_transform(np.array(selected_y_train_true).reshape(-1, 1)).ravel()
selected_y_train_pred_inv = pt.inverse_transform(np.array(selected_y_train_pred).reshape(-1, 1)).ravel()

selected_y_true_inv = pt.inverse_transform(np.array(selected_y_true).reshape(-1, 1)).ravel()
selected_y_pred_inv = pt.inverse_transform(np.array(selected_y_pred).reshape(-1, 1)).ravel()

plt.figure(figsize=(8, 8))

plt.style.use('../data_extraction/plots_and_figures/lamalab.mplstyle')

plt.scatter(selected_y_train_true_inv, selected_y_train_pred_inv, alpha=0.7, label='Train Data', color='#661124')
plt.plot([min(selected_y_train_true_inv), max(selected_y_train_true_inv)], 
         [min(selected_y_train_true_inv), max(selected_y_train_true_inv)], 
         color='grey', linestyle='--')  # Linie y=x

plt.scatter(selected_y_true_inv, selected_y_pred_inv, alpha=0.7, label='Test Data', color='#194A81')
plt.xlabel(r'True $r_{\text{product}}$', fontsize=16)
plt.ylabel(r'Predicted $r_{\text{product}}$', fontsize=16)
plt.xlim(-0.1, 2)
plt.ylim((-0.1,2))
plt.legend(fontsize=12)

plt.savefig('pred_200_XGBoost_just_monomer.png', dpi=300, bbox_inches='tight')
plt.show()
